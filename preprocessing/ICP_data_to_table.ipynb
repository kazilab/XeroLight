# %%
from data_import_2 import process_isotope_data

# %%
# Call the function with the path to your CSV file
data, sample_name, isotope_names = process_isotope_data('240130 Isotopes in hair.csv', 'exp_id')

# %%
data
# Out:
#        sample_name       param0        param1                 param2   param3  \
# 0            Blank  Raw.Average             0         6Li (M-SQ-KED)  Y (cps)
# 1            Blank  Raw.Average             0         7Li (M-SQ-KED)  Y (cps)
# 2            Blank  Raw.Average             0         10B (M-SQ-KED)  Y (cps)
# 3            Blank  Raw.Average             0         11B (M-SQ-KED)  Y (cps)
# 4            Blank  Raw.Average             0        24Mg (M-SQ-KED)  Y (cps)
# ...            ...          ...           ...                    ...      ...
# 645535   TUBEBLANK    iCAPQNova        ExtCal  Total Dilution Factor      NaN
# 645536   TUBEBLANK    iCAPQNova        ExtCal             Limits Set      NaN
# 645537   TUBEBLANK    ESI_SC4DX   Rack Number                    NaN      NaN
# 645538   TUBEBLANK    ESI_SC4DX  Vial Numbers                    NaN      NaN
# 645539   TUBEBLANK          NaN           NaN                    NaN      NaN
#
# ...

# %%
sample_name
# Out:
#               sample_name
# sample_index
# 1                   Blank
# 2                   Blank
# 3             JHBUI 8375
# 4             JHBUI 8383
# 5             JHBUI 8384
# ...                   ...
# 141                 Blank
# 142             TUBEBLANK
# 143             TUBEBLANK
# 144             TUBEBLANK
# 145             TUBEBLANK
#
# [145 rows x 1 columns]

# %%
isotope_names
# Out:
# row_index           param2 method_id
# isotopes
# 6Li         6Li (M-SQ-KED)  M-SQ-KED
# 7Li         7Li (M-SQ-KED)  M-SQ-KED
# 10B         10B (M-SQ-KED)  M-SQ-KED
# 11B         11B (M-SQ-KED)  M-SQ-KED
# 24Mg       24Mg (M-SQ-KED)  M-SQ-KED
# ...                    ...       ...
# 232U       232U (M-SQ-KED)  M-SQ-KED
# 234U       234U (M-SQ-KED)  M-SQ-KED
# 235U       235U (M-SQ-KED)  M-SQ-KED
# 236U       236U (M-SQ-KED)  M-SQ-KED
# 238U       238U (M-SQ-KED)  M-SQ-KED
#
# [122 rows x 2 columns]

# %%
# Call the function with the path to your CSV file
data, sample_name, isotope_names = process_isotope_data('240702 Test av ny ICP-metod (nyavarianten).csv', 'exp_id2')

# %%
data
# Out:
#      sample_name       param0        param1                 param2   param3  \
# 0          BLANK  Raw.Average             0         9Be (M-SQ-KED)  Y (cps)
# 1          BLANK  Raw.Average             0         10B (M-SQ-KED)  Y (cps)
# 2          BLANK  Raw.Average             0         11B (M-SQ-KED)  Y (cps)
# 3          BLANK  Raw.Average             0        23Na (M-SQ-KED)  Y (cps)
# 4          BLANK  Raw.Average             0        24Mg (M-SQ-KED)  Y (cps)
# ...          ...          ...           ...                    ...      ...
# 8017       BLANK    iCAPQNova        ExtCal  Total Dilution Factor      NaN
# 8018       BLANK    iCAPQNova        ExtCal             Limits Set      NaN
# 8019       BLANK    ESI_SC4DX   Rack Number                    NaN      NaN
# 8020       BLANK    ESI_SC4DX  Vial Numbers                    NaN      NaN
# 8021       BLANK          NaN           NaN                    NaN      NaN
#
# ...

# %%
sample_name
# Out:
#                  sample_name
# sample_index
# 1                      BLANK
# 2             IN-HOUSE STD 1
# 3             IN-HOUSE STD 2
# 4             IN-HOUSE STD 3
# 5             IN-HOUSE STD 4
# 6             IN-HOUSE STD 5
# 7                      BLANK

# %%
isotope_names
# Out:
# row_index            param2 method_id
# isotopes
# 9Be          9Be (M-SQ-KED)  M-SQ-KED
# 10B          10B (M-SQ-KED)  M-SQ-KED
# 11B          11B (M-SQ-KED)  M-SQ-KED
# 23Na        23Na (M-SQ-KED)  M-SQ-KED
# 24Mg        24Mg (M-SQ-KED)  M-SQ-KED
# ...                     ...       ...
# 206Pb      206Pb (M-SQ-KED)  M-SQ-KED
# 207Pb      207Pb (M-SQ-KED)  M-SQ-KED
# 208Pb      208Pb (M-SQ-KED)  M-SQ-KED
# 236U        236U (M-SQ-KED)  M-SQ-KED
# 238U        238U (M-SQ-KED)  M-SQ-KED
#
# [87 rows x 2 columns]
